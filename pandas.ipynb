# %% [markdown]
# <a href="https://colab.research.google.com/github/vicmanw1ld/IA/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# CREACIÓN DEL OBJETO SERIES

# %%
#creación del objeto series
s = pd.Series([2,4,6,8,10])
s #lo de la izda es un índice y a la derecha lo que hemos puesto
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
# Creación de un objeto Series inicializándolo con un diccionario de Python
altura = {"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}
s = pd.Series(altura)
print(s) #me crea el indice con los nombres
# Out:
# Santiago    187
# Pedro       178
# Julia       170
# Ana         165
# dtype: int64

# %%
# Creación de un objeto Series inicializándolo con algunos
# de los elementos de un diccionario de Python
altura = {"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}
s = pd.Series(altura, index = ["Pedro", "Julia"])
print(s)
# Out:
# Pedro    178
# Julia    170
# dtype: int64

# %%
# Creación de un objeto Series inicializandolo con un escalar
s = pd.Series(34, ["test1", "test2", "test3"])
print(s)
# Out:
# test1    34
# test2    34
# test3    34
# dtype: int64

# %% [markdown]
# ACCESO AL OBJETO SERIES

# %%
#Cada elemento en un objeto Series tiene un identificador único que se denomina **_index label_**.
# Creación de un objeto Series
s = pd.Series([2, 4, 6, 8], index=["num1", "num2", "num3", "num4"])
print(s)
# Out:
# num1    2
# num2    4
# num3    6
# num4    8
# dtype: int64

# %%
# Accediendo al tercer elemento del objeto
s["num3"]
# Nos da el elemento 6, tiene mejores características pq puedes acceder a el por el numero de posición
s[2]
# Out:
# <ipython-input-75-7766c29a1787>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[2]
# np.int64(6)

# %%
# loc es la forma estándar de acceder a un elemento de un objeto Series por atributo
s.loc["num3"]
#lo hacemos cuando queremos acceder a un elemento por el indice con loc
# Out:
# np.int64(6)

# %%
# iloc es la forma estándar de acceder a un elemento de un objeto Series por posición
s.iloc[2]
# Out:
# np.int64(6)

# %%
# Accediendo al segundo y tercer elemento por posición
s.iloc[2:4]
# Out:
# num3    6
# num4    8
# dtype: int64

# %% [markdown]
# Operaciones aritméticas con Series

# %%
# Creacion de un objeto Series
s = pd.Series([2, 4, 6, 8, 10])
print(s)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
# Los objeto Series son similares y compatibles con los Arrays de Numpy
import numpy as np
# Ufunc de Numpy para sumar los elementos de un Array
np.sum(s) #me suma todos los números del objeto series
# El resto de operaciones aritméticas de Numpy sobre Arrays también son posibles
# Más información al respecto en la Introducción a Numpy
s * 2
# Out:
# 0     4
# 1     8
# 2    12
# 3    16
# 4    20
# dtype: int64

# %% [markdown]
# REPRESENTACIÓN GRÁFICA DE UN OBJETO SERIES

# %%
# Creación de un objeto Series denominado Temperaturas
temperaturas = [4.4, 5.1, 6.1, 6.2, 6.1, 6.1, 5.7, 5.2, 4.7, 4.1, 3.9]
s = pd.Series(temperaturas, name="Temperaturas")
s
# Out:
# 0     4.4
# 1     5.1
# 2     6.1
# 3     6.2
# 4     6.1
# 5     6.1
# 6     5.7
# 7     5.2
# 8     4.7
# 9     4.1
# 10    3.9
# Name: Temperaturas, dtype: float64

# %%
# Representación gráfica del objeto Series
# %matplotlib inline
import matplotlib.pyplot as plt

s.plot()
plt.show()

# %% [markdown]
# CREACIÓN DE UN OBJETO DATAFRAME

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

df = pd.DataFrame(personas)
df
#NaN es un valor nulo o que no existe
# Out:
#           peso  altura  hijos
# Ana         56     165    NaN
# Julia       64     170    3.0
# Pedro       90     178    2.0
# Santiago    84     187    NaN

# %% [markdown]
# Puede forzarse al DataFrame a que presente unas columnas determinadas y en un orden determinado

# %%
# Creación de un DataFrame inicializándolo con algunos elementos de un diccionario
# de objetos Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

df = pd.DataFrame(personas, columns = ["altura", "peso"], index = ["Ana", "Julia", "Santiago"])
df
# VER LOS MÉTODOS QUE TIENE Y JUGAR UN POCO
# Out:
#           altura  peso
# Ana          165    56
# Julia        170    64
# Santiago     187    84

# %% [markdown]
# | Método          | Descripción                                  |
# | --------------- | -------------------------------------------- |
# | `df.head()`     | Muestra las primeras 5 filas                 |
# | `df.tail()`     | Muestra las últimas 5 filas                  |
# | `df.info()`     | Información general (tipos, nulos, memoria)  |
# | `df.shape`      | Muestra el número de filas y columnas        |
# | `df.columns`    | Nombres de las columnas                      |
# | `df.index`      | Índices del DataFrame                        |
# | `df.describe()` | Estadísticas resumen para columnas numéricas |
# | `df.dtypes`     | Tipos de datos por columna                   |
#
# | Método                                   | Descripción                    |
# | ---------------------------------------- | ------------------------------ |
# | `df["col"]`                              | Accede a una columna           |
# | `df.loc["Ana"]`                          | Accede a una fila por etiqueta |
# | `df.iloc[0]`                             | Accede a una fila por posición |
# | `df["nueva_col"] = ...`                  | Agrega una columna             |
# | `df.drop(columns=["peso"])`              | Elimina columnas               |
# | `df.drop(index=["Pedro"])`               | Elimina filas                  |
# | `df.rename(columns={"altura": "talla"})` | Renombra columnas              |
#
# | Método                         | Descripción                      |
# | ------------------------------ | -------------------------------- |
# | `df.mean()`                    | Media de cada columna numérica   |
# | `df.sum()`                     | Suma de cada columna             |
# | `df.max()` / `df.min()`        | Máximo y mínimo                  |
# | `df.apply()`                   | Aplica una función personalizada |
# | `df.sort_values("peso")`       | Ordena por columna               |
# | `df.isnull()` / `df.notnull()` | Localiza valores nulos           |
#
# | Método         | Descripción                     |
# | -------------- | ------------------------------- |
# | `df.fillna(0)` | Rellena nulos con 0             |
# | `df.dropna()`  | Elimina filas con valores nulos |

# %%
# vamos a hacer el IMC añadiendo una columna IMC = peso/altura en m ^2
df["IMC"] = df["peso"] / ((df["altura"] / 100) ** 2)
df
#Ahora lo vamos a clasificar por ESTADO incluyendo el IMC
def clasificar_imc(imc):
    if imc < 18.5:
        return "delgado"
    elif imc < 25:
        return "medio"
    else:
        return "gordo"

df["estado"] = df["IMC"].apply(clasificar_imc)
df
# Out:
#           altura  peso        IMC estado
# Ana          165    56  20.569330  medio
# Julia        170    64  22.145329  medio
# Santiago     187    84  24.021276  medio

# %%
#filtrar por altura
altos = df[df["altura"] > 170]
altos
# Out:
#           altura  peso        IMC estado
# Santiago     187    84  24.021276  medio

# %%
# El que más pesa, con la función idxmax
persona_mas_peso = df["peso"].idxmax()
peso_mas_alto = df["peso"].max()

print(f"La persona con más peso es {persona_mas_peso} con {peso_mas_alto} kg.")
# Out:
# La persona con más peso es Santiago con 84 kg.

# %%
#Se pueden usar funciones de NUMPY con el df
peso_max = np.max(df["peso"])
peso_min = np.min(df["peso"])
peso_medio = np.mean(df["peso"])
peso_std = np.std(df["peso"])

print("Peso máximo:", peso_max)
print("Peso mínimo:", peso_min)
print("Peso medio:", peso_medio)
print("Desviación estándar:", peso_std)
# Out:
# Peso máximo: 84
# Peso mínimo: 56
# Peso medio: 68.0
# Desviación estándar: 11.775681155103795

# %%
#Si creas una columna el df se transforma, no solo lo vemos y ya si no queremos que se añada hay que trabajar con df_copia
df_copia = df.copy()
df_copia["nueva_columna"] = ...

# %%
#Puede forzarse al DataFrame a que presente unas columnas determinadas y en un orden determinado
# Creación de un DataFrame inicializándolo con algunos elementos de un diccionario
# de objetos Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

df = pd.DataFrame(
        personas,
        columns = ["altura", "peso"],
        index = ["Ana", "Julia", "Santiago"])
df
# Out:
#           altura  peso
# Ana          165    56
# Julia        170    64
# Santiago     187    84

# %%
# Creación de un DataFrame inicializándolo con una lista de listas de Python
# Importante: Deben especificarse las columnas e indices por separado
valores = [
    [185, 4, 76],
    [170, 0, 65],
    [190, 1, 89]
]

df = pd.DataFrame(
        valores,
        columns = ["altura", "hijos", "peso"],
        index = ["Pedro", "Ana", "Juan"])
df
# Out:
#        altura  hijos  peso
# Pedro     185      4    76
# Ana       170      0    65
# Juan      190      1    89

# %%
# Creación de un DataFrame inicializándolo con un diccionario de Python
personas = {
    "altura": {"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165},
    "peso": {"Santiago": 87, "Pedro": 78, "Julia": 70, "Ana": 65}}

df = pd.DataFrame(personas)
df
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70
# Ana          165    65

# %% [markdown]
# ACCESO A LOS ELEMENTOS DE UN DATAFRAME

# %%
df["peso"]
# Out:
# Santiago    87
# Pedro       78
# Julia       70
# Ana         65
# Name: peso, dtype: int64

# %%
df[["peso", "altura"]]
# Out:
#           peso  altura
# Santiago    87     187
# Pedro       78     178
# Julia       70     170
# Ana         65     165

# %% [markdown]
# PUEDEN COMBINARSE CON EXPRESIONES BOOLEANAS

# %%
# Pueden combinarse los metodos anteriores con expresiones booleanas
df[df["peso"] > 80]
# Out:
#           altura  peso
# Santiago     187    87

# %%
# Pueden combinarse los metodos anteriores con expresiones booleanas
df[(df["peso"] > 80) & (df["altura"] > 180)]
# Out:
#           altura  peso
# Santiago     187    87

# %%
df
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70
# Ana          165    65

# %%
df.loc["Pedro"] #accedemos a los índices
# Out:
# altura    178
# peso       78
# Name: Pedro, dtype: int64

# %%
df.iloc[2] #también por el número de índice nos dará Julia
# Out:
# altura    170
# peso       70
# Name: Julia, dtype: int64

# %%
#df.iloc[1:3] # nos dará Pedro y Julia
df.loc[:]# nos da todos
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70
# Ana          165    65

# %% [markdown]
# CONSULTA AVANZADA QUERYS

# %%
df.query("altura >= 170 and peso > 60")
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70

# %% [markdown]
# COPIA DE UN DF

# %%
# Copia del DataFrame df en df_copy
# Importante: Al modificar un elemento de df_copy no se modifica df
df_copy = df.copy()
df_copy #Son objetos mutables se pueden modificar
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70
# Ana          165    65

# %%
# Añadir una nueva columna al DataFrame
df_copy["cumpleaños"] = [1990, 1987, 1980, 1994]
df_copy # Nos añade la columna si no existe
# la vamos a añadir en df y seguimos
df["cumpleaños"] = [1990, 1987, 1980, 1994]
df
# Out:
#           altura  peso  cumpleaños
# Santiago     187    87        1990
# Pedro        178    78        1987
# Julia        170    70        1980
# Ana          165    65        1994

# %%
# Añadir una nueva columna calculada al DataFrame
df["años"] = 2025 - df["cumpleaños"] #nos calcula cuantos años tiene, como en bbdd las funciones
df #realiza la resta de 2025 - el año de nacimiento cada uno de ellos, un bucle tardaría mucho más
# Out:
#           altura  peso  cumpleaños  años
# Santiago     187    87        1990    35
# Pedro        178    78        1987    38
# Julia        170    70        1980    45
# Ana          165    65        1994    31

# %% [markdown]
# **MÉTDODO ASSING**

# %%
#Llegará un momento en que queramos crear un nuevo dataframe con nuevas columnas pero queramos guardar el que tenemos
# Añadir una nueva columna creando un DataFrame nuevo
df_mod = df.assign(mascotas = [1, 3, 0, 0])
df_mod
# Out:
#           altura  peso  cumpleaños  años  mascotas
# Santiago     187    87        1990    35         1
# Pedro        178    78        1987    38         3
# Julia        170    70        1980    45         0
# Ana          165    65        1994    31         0

# %%
df # aqui nos deja las columnas que teniamos
# Out:
#           altura  peso  cumpleaños  años
# Santiago     187    87        1990    35
# Pedro        178    78        1987    38
# Julia        170    70        1980    45
# Ana          165    65        1994    31

# %%
# Eliminar una columna existente del DataFrame
del df["peso"] #Se carga la columna hijos
df
# Out:
#           altura  cumpleaños  años
# Santiago     187        1990    35
# Pedro        178        1987    38
# Julia        170        1980    45
# Ana          165        1994    31

# %%
# Eliminar una columna existente devolviendo una copia del DataFrame resultante
df_mod = df.drop(["altura"], axis=1)
df_mod
# Out:
#           cumpleaños  años
# Santiago        1990    35
# Pedro           1987    38
# Julia           1980    45
# Ana             1994    31

# %%
df
# Out:
#           altura  cumpleaños  años
# Santiago     187        1990    35
# Pedro        178        1987    38
# Julia        170        1980    45
# Ana          165        1994    31

# %% [markdown]
# EVALUACIÓN DE EXPRESIONES SOBRE UN DF

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

df = pd.DataFrame(personas)
df
# Out:
#           peso  altura  hijos
# Ana         56     165    NaN
# Julia       64     170    3.0
# Pedro       90     178    2.0
# Santiago    84     187    NaN

# %%
# Evaluar una función sobre una columna del DataFrame
resultado = df.eval("peso / 2", engine='python') #Esto le dice a pandas.eval() que no use numexpr, sino el motor nativo de Python
#que es más flexible aunque algo más lento (pero para estas cosas va sobrado).
print(resultado)
# Out:
# Ana         28.0
# Julia       32.0
# Pedro       45.0
# Santiago    42.0
# Name: peso, dtype: float64

# %%
# Asignar el valor resultante como una nueva columna
df.eval("media_altura = altura / 2", inplace=True, engine='python')
df
# Out:
#           peso  altura  hijos  media_altura
# Ana         56     165    NaN          82.5
# Julia       64     170    3.0          85.0
# Pedro       90     178    2.0          89.0
# Santiago    84     187    NaN          93.5

# %%
# Evaluar una función utilizando una variable local
max_altura = 180

df.eval("altura > @max_altura", engine='python') # Que índices cumplen con esta condición
# Out:
# Ana         False
# Julia       False
# Pedro       False
# Santiago     True
# Name: altura, dtype: bool

# %%
# Aplicar una función externa a una columna del DataFrame, nos suma 2 al peso
def func(x):
    return x + 2

df["peso"].apply(func) #Se aplica con el método apply
# Out:
# Ana         58
# Julia       66
# Pedro       92
# Santiago    86
# Name: peso, dtype: int64

# %% [markdown]
# GUARDAR Y CARGAR EL DF

# %%
# Guardar el DataFrame como CSV, HTML y JSON
df.to_csv("df_personas.csv")
df.to_html("df_personas.html")
df.to_json("df_personas.json")
# Cargar el DataFrame en Jupyter
df2 = pd.read_csv("df_personas.csv")
# Cargar el DataFrame con la primera columna correctamente asignada
df2 = pd.read_csv("df_personas.csv", index_col=0) # AQUI LE DIGO QUE LA COLUMNA 0 ES EL ÍNDICE
df2
